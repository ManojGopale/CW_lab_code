# %% [markdown]
# # Trace Collection: Different devices, different executables

# %% [markdown]
# ---
# We will be collecting traces from different devices. Each device will have mutliple traces fro different executables, such as ANSII+masked, MBEDTLS, HWAES
#
# ---

# %%
#SCOPETYPE = 'OPENADC'
#PLATFORM = 'CW308_STM32L4' #'CWLITEARM'
PLATFORM = 'CW308_STM32F4'
#PLATFORM = 'CW308_STM32F3'

# #CRYPTO_TARGET = "HWAES" #"MBEDTLS"
# CRYPTO_TARGET = None
SS_VER = 'SS_VER_1_1'
# #CHECK_CORR = False ##From CW_lite code

# %%
# %run "../../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# (ChipWhisperer NAEUSB WARNING|File naeusb.py:743) Your firmware (0.30) is outdated - latest is 0.65 See https://chipwhisperer.readthedocs.io/en/latest/firmware.html for more information
# INFO: Found ChipWhisperer😍
# scope.gain.mode                          changed from low                       to high
# scope.gain.gain                          changed from 0                         to 30
# scope.gain.db                            changed from 5.5                       to 24.8359375
# scope.adc.basic_mode                     changed from low                       to rising_edge
# scope.adc.samples                        changed from 24400                     to 5000
# scope.adc.trig_count                     changed from 7713013                   to 20229761
# scope.clock.adc_src                      changed from clkgen_x1                 to clkgen_x4
# scope.clock.adc_freq                     changed from 7384609                   to 96000000
# scope.clock.adc_rate                     changed from 7384609.0                 to 96000000.0
# scope.clock.clkgen_div                   changed from 1                         to 26
# scope.clock.clkgen_freq                  changed from 192000000.0               to 7384615.384615385
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen

# %%
scope.default_setup()
target = cw.target(scope)
# target.baud = 20834
print(target.baud)
print(scope)
# Out:
# scope.clock.adc_freq                     changed from 96000000                  to 29538459
# scope.clock.adc_rate                     changed from 96000000.0                to 29538459.0
# 38400
# cwlite Device
# sn         = 50203220313038543230333131303035
# fw_version =
#     major = 0
#     minor = 30
#     debug = 0
# gain =
#     mode = high
#     gain = 30
#     db   = 24.8359375
# adc =
#     state          = False
#     basic_mode     = rising_edge
#     timeout        = 2
#     offset         = 0
#     presamples     = 0
#     samples        = 5000
#     decimate       = 1
#     trig_count     = 20229761
#     fifo_fill_mode = normal
# clock =
#     adc_src       = clkgen_x4
#     adc_phase     = 0
#     adc_freq      = 29538459
#     adc_rate      = 29538459.0
#     adc_locked    = True
#     freq_ctr      = 0
#     freq_ctr_src  = extclk
#     clkgen_src    = system
#     extclk_freq   = 10000000
#     clkgen_mul    = 2
#     clkgen_div    = 26
#     clkgen_freq   = 7384615.384615385
#     clkgen_locked = True
# trigger =
#     triggers = tio4
#     module   = basic
# io =
#     tio1         = serial_rx
#     tio2         = serial_tx
#     tio3         = high_z
#     tio4         = high_z
#     pdid         = high_z
#     pdic         = high_z
#     nrst         = high_z
#     glitch_hp    = False
#     glitch_lp    = False
#     extclk_src   = hs1
#     hs2          = clkgen
#     target_pwr   = True
#     tio_states   = (1, 1, 0, 0)
#     cdc_settings = bytearray(b'\x00\x00')
# glitch =
#     clk_src     = target
#     width       = 10.15625
#     width_fine  = 0
#     offset      = 10.15625
#     offset_fine = 0
#     trigger_src = manual
#     arm_timing  = after_scope
#     ext_offset  = 0
#     repeat      = 1
#     output      = clock_xor

# %%
#fw_path = '../../../hardware/victims/firmware/simpleserial-aes-checkTraces/simpleserial-aes-{}.hex'.format(PLATFORM)
#fw_path = '/home/manoj/Documents/chipwhisperer-firmware/simpleserial-aes/simpleserial-aes_CW308-STM32L4_MASKEDAES_ANSSI.hex'
#fw_path = '/home/manoj/Documents/chipwhisperer-firmware/simpleserial-aes/simpleserial-aes_CW308-STM32L4_TINYAES128C.hex'
#fw_path = '/home/manoj/Documents/chipwhisperer-firmware/simpleserial-aes/simpleserial-aes_CW308-STM32L4_MASKEDAES_ANSSI+UNROLLED.hex'
#fw_path = '/home/manoj/Documents/chipwhisperer-firmware/simpleserial-aes/simpleserial-aes_CW308-STM32L4_MBEDTLS.hex'
#fw_path = '/home/manoj/Documents/chipwhisperer-firmware/simpleserial-aes/simpleserial-aes_CW308-STM32L4_HWAES.hex'

#fw_path = '/home/manoj/Documents/chipwhisperer-firmware/simpleserial-aes/simpleserial-aes_CW308-STM32F3_TINYAES128C.hex'
#fw_path = '/home/manoj/Documents/chipwhisperer-firmware/simpleserial-aes/simpleserial-aes_CW308-STM32F3_MBEDTLS.hex'
#fw_path = "/home/manoj/Documents/chipwhisperer-firmware/simpleserial-aes/simpleserial-aes_CW308-STM32F4_TINYAES128C.hex"

fw_path  = "/home/manoj/Documents/chipwhisperer-firmware/simpleserial-aes/simpleserial-aes_CW308-STM32F4_MBEDTLS.hex"

cw.program_target(scope, prog, fw_path, baud=38400)
# Out:
# Detected known STMF32: STM32F40xxx/41xxx
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 16451 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 16451 bytes

# %%
scope.default_setup()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 scope.default_setup()
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/capture/scopes/OpenADC.py:334, in OpenADC.default_setup(self, verbose)
#     314 def default_setup(self, verbose=True):
#     315     """Sets up sane capture defaults for this scope
#     316
#     317      *  25dB gain
#    (...)
#     332         Added default setup for OpenADC
#     333     """
# --> 334     scope_dict_pre = self._dict_repr()
#     335     self.gain.db = 25
#     336     self.adc.samples = 5000
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/capture/scopes/OpenADC.py:956, in OpenADC._dict_repr(self)
#     954 def _dict_repr(self) -> dict:
#     955     rtn : Dict[str, Any] = {}
# --> 956     rtn['sn'] = self.sn
#     957     if self._is_husky:
#     958         rtn['fpga_buildtime'] = self.fpga_buildtime
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/capture/api/cwcommon.py:155, in ChipWhispererCommonInterface.sn(self)
#     149 @property
#     150 def sn(self) -> str:
#     151     """The USB serial number of this scope.
#     152
#     153     Can be passed to cw.scope() to specify which ChipWhisperer to connect to
#     154     """
# --> 155     return self._getNAEUSB().snum
#
# AttributeError: 'NoneType' object has no attribute 'snum'

# %%
print(scope.adc.presamples)
print(scope.adc.timeout)
print(scope.clock.adc_src)
print(scope.clock.adc_freq)
print(scope.clock.adc_rate)
print(scope.clock.adc_locked)
print(scope.clock.freq_ctr)
print(scope.clock.freq_ctr_src)
print(scope.clock.clkgen_src)
print(scope.clock.extclk_freq)
print(scope.clock.clkgen_mul)
print(scope.clock.clkgen_div)
print(scope.clock.clkgen_freq)
print(scope.gain)
# Out:
# 0
# 2
# clkgen_x4
# 276363281
# 276363281.0
# True
# 0
# extclk
# system
# 10000000
# 2
# 26
# 7384615.384615385
# mode = high
# gain = 30
# db   = 24.8359375

# %%
scope.adc.samples = 1500
#scope.adc.offset = 24400
#scope.clock.clkgen_freq = 4e6
scope.clock.adc_src = "clkgen_x1"
# target = cw.target(scope)
#target.baud = 20834
print(target.baud)
#scope.adc.timeout = 60
#scope.adc.default()
# Out:
# 38400

# %%
print(target.read())

# %%
print(scope.adc.presamples)
print(scope.adc.samples)
print(scope.adc.timeout)
print(scope.clock.adc_src)
print(scope.clock.adc_freq)
print(scope.clock.adc_rate)
print(scope.clock.adc_locked)
print(scope.clock.freq_ctr)
print(scope.clock.freq_ctr_src)
print(scope.clock.clkgen_src)
print(scope.clock.extclk_freq)
print(scope.clock.clkgen_mul)
print(scope.clock.clkgen_div)
print(scope.clock.clkgen_freq)
print(scope.gain)
# Out:
# 0
# 1500
# 2
# clkgen_x1
# 7384620
# 7384620.0
# True
# 0
# extclk
# system
# 10000000
# 2
# 26
# 7384615.384615385
# mode = high
# gain = 30
# db   = 24.8359375

# %%
#Capture Traces
from tqdm import tnrange, trange
import numpy as np
import time

ktp = cw.ktp.Basic()
ktp.fixed_key = False

traces = []
N = 15000  # Number of traces
prjDir = "/mnt/hgfs/trace_key_l443_1500_15kAdd/"

for fileNum in range(256):
    project = cw.create_project(prjDir + "key_" + str(fileNum) + ".cwp", overwrite=True)

    for i in trange(N, desc='Capturing traces:' + str(fileNum)):
        key, text = ktp.next()  # manual creation of a key, text pair can be substituted here
        key[0] = fileNum

        trace = cw.capture_trace(scope, target, text, key)
        if trace is None:
            continue
        project.traces.append(trace)

    try:
        print(scope.adc.trig_count) # print if this exists
    except:
        pass
    project.save()
    project.close()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[36], line 14
#      11 prjDir = "/mnt/hgfs/trace_key_l443_1500_15kAdd/"
#      13 for fileNum in range(256):
# ---> 14     project = cw.create_project(prjDir + "key_" + str(fileNum) + ".cwp", overwrite=True)
#      16     for i in trange(N, desc='Capturing traces:' + str(fileNum)):
#      17         key, text = ktp.next()  # manual creation of a key, text pair can be substituted here
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/__init__.py:235, in create_project(filename, overwrite)
#     232 filename = os.path.abspath(os.path.expanduser(filename))
#     234 proj = project.Project()
# --> 235 proj.setFilename(filename)
#     237 return proj
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/common/api/ProjectFormat.py:275, in Project.setFilename(self, f)
#     273 self.config.filename = f
#     274 self.datadirectory = os.path.splitext(self.filename)[0] + "_data"
# --> 275 self.createDataDirectory()
#     276 self.sigStatusChanged.emit()
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/common/api/ProjectFormat.py:281, in Project.createDataDirectory(self)
#     278 def createDataDirectory(self):
#     279     # Check if data-directory exists?
#     280     if not os.path.isdir(self.datadirectory):
# --> 281         os.makedirs(self.datadirectory)
#     283     # Make trace storage directory too
#     284     if not os.path.isdir(os.path.join(self.datadirectory, 'traces')):
#
# File ~/.pyenv/versions/3.9.5/lib/python3.9/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File ~/.pyenv/versions/3.9.5/lib/python3.9/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# PermissionError: [Errno 13] Permission denied: '/mnt/hgfs/trace_key_l443_1500_15kAdd'

# %%
np.random.choice(256,1)[0]

# %%
#Capture Traces
from tqdm import tnrange, trange
import numpy as np
import time

ktp = cw.ktp.Basic()
ktp.fixed_key = False

traces = []
N = 100  # Number of traces
project = cw.create_project("traces/f415_mbedtls_1500.cwp", overwrite=True)

for i in trange(N, desc='Capturing traces'):
    key, text = ktp.next()  # manual creation of a key, text pair can be substituted here
    key[0] = 0
#     for k in range(len(key)):
#         key[k] = 150
        
    #print(f"key= {key}")

    trace = cw.capture_trace(scope, target, text, key)
    if trace is None:
        continue
    project.traces.append(trace)

try:
    print(scope.adc.trig_count) # print if this exists
except:
    pass
project.save()
# Out:
# Capturing traces: 100%|█████████████████████████████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 23.04it/s]
# 2895

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import chipwhisperer as cw

project = cw.open_project("traces/f415_mbedtls_1500.cwp")
print(project.location)
xShape = project.traces[0].wave.shape[0]
x=np.linspace(0,xShape-1, xShape)

#savePath = "/home/manojgopale/Documents/chipwhisperer/jupyter/courses/sca201/img/sca201_images/" + prjName + ".jpg"

fig, axs = plt.subplots(4, sharex=True, sharey= True, figsize=(30,10))
axs[0].plot(x,project.traces[0].wave)
axs[0].set_title(project.traces[0].key)
axs[1].plot(x,project.traces[1].wave)
axs[1].set_title(project.traces[1].key)
axs[2].plot(x,project.traces[8].wave)
axs[2].set_title(project.traces[8].key)
axs[3].plot(x,project.traces[9].wave)
axs[3].set_title(project.traces[9].key)

fig.savefig("img/l443_1500.png")
# Out:
# /home/manoj/Documents/chipwhisperer/jupyter/courses/sca201/traces

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

project1 = cw.open_project("traces/ansii_masked_unrolled_7p38mhzclock_clk_x1.cwp")
project2 = cw.open_project("traces/ansii_masked_unrolled_7p38mhzclock_clk_x1_24400_offset.cwp")
print(project.location)
traceList=[]
keyList = []
df = pd.DataFrame(columns=['trace', 'key'])

for idx, (trace1, trace2) in enumerate(zip(project1.traces,project2.traces)):
    #print(f"trace1= {trace1.wave.shape}, trace2= {trace2.wave.shape}")
    traceList.append(np.concatenate((trace1.wave,trace2.wave), axis=0))
    keyList.append(trace1.key)

df["trace"] = traceList
df["key"] = keyList

#print(f"fullData shape= {len(traceList)}\ndf= {df.head}\ndf_1 = {df.iloc[0].shape}")

xShape = df.trace.iloc[0].shape[0]
x=np.linspace(0,xShape-1, xShape)

#savePath = "/home/manojgopale/Documents/chipwhisperer/jupyter/courses/sca201/img/sca201_images/" + prjName + ".jpg"

fig, axs = plt.subplots(4, sharex=True, figsize=(30,10))
axs[0].plot(x,df.trace.iloc[0])
axs[0].set_title(df.key.iloc[0])
axs[1].plot(x,df.trace.iloc[1])
axs[1].set_title(df.key.iloc[1])
axs[2].plot(x,df.trace.iloc[8])
axs[2].set_title(df.key.iloc[8])
axs[3].plot(x,df.trace.iloc[9])
axs[3].set_title(df.key.iloc[9])

fig.savefig("img/ansii_masked_unrolled_7p38mhzclock_clk_x1_48800TimeSamples.png")

# %%
## Use this to save to npz, pkl format is not compatible across different versions of python.
from tqdm import tnrange, trange
import chipwhisperer as cw
import pandas as pd
import os
import numpy as np

## dataFrame to store all the traces
df_new = pd.DataFrame(columns=['trace', 'key'])
traceList = []
keyList = []

trainSize= 15000
devSize = 500
testSize = 500
# ##Adding traces for not complete 
# keysNotDone = [204, 228, 244, 245]
# count = 0
prjDir = "/mnt/hgfs/trace_key_l443_1500_15kAdd/"
saveDir = "/mnt/hgfs/trace_key_l443_1500_15kAdd_dataset/"

for fileNum in trange(256, desc='Splitting data'):
    df_new = pd.DataFrame(columns=['trace', 'key'])
    traceList = []
    keyList = []
    print("Started key= %s" %(fileNum))
    prjName = "key_" + str(fileNum)
    new_project = cw.open_project(prjDir + prjName + ".cwp")
    for index, trace in enumerate(new_project.traces):
        #df_new = df_new.append({'trace': trace.wave, 'key': trace.key}, ignore_index=True)
        traceList.append(trace.wave)
        keyList.append(trace.key)

    ##Create trace and key dataFrame        
    df_new["trace"] = traceList
    df_new["key"] = keyList

    ##Shuffle the dataframe before splitting in test, dev and train
    df_new = df_new.sample(frac=1).reset_index(drop=True)
    
    ##Split it in train, dev and test
    df_train = df_new.iloc[0:trainSize, : ].reset_index(drop=True)
# #     df_dev   = df_new.iloc[trainSize:trainSize+devSize, : ].reset_index(drop=True)
# #     df_test  = df_new.iloc[trainSize+devSize:trainSize+devSize+testSize, : ].reset_index(drop=True)
    
    ##Save it to pkl
    saveTrain = saveDir + "/train_" + str(fileNum) + ".npz"
# #     saveDev   = saveDir + "/dev_" + str(fileNum) + ".npz"
# #     saveTest  = saveDir + "/test_" + str(fileNum) + ".npz"

    if (not os.path.exists(saveTrain)):
        np.savez_compressed(saveTrain, data=df_train)
        print("Saved fileNum= %s to %s" %(fileNum, saveTrain))
        
# #     if (not os.path.exists(saveDev)):
# #         np.savez_compressed(saveDev, data=df_dev)
# #         print("Saved key= %s to %s" %(fileNum, saveDev))
    
# #     if (not os.path.exists(saveTest)):
# #         np.savez_compressed(saveTest, data=df_test)
# #         print("Saved key= %s to %s" %(fileNum, saveTest))

    print("Done saving files for file= %s" %(fileNum))
    ##Clean al dataframe's before next loop
    df_new = df_new.drop(df_new.columns, axis=1)
    df_train = None
#     df_dev = None
#     df_test = None


## Add these to the csv files.
print("Done saving all the traces\n")
# Out:
# Splitting data:   0%|                                                                                                                                   | 0/256 [00:00<?, ?it/s]
# Started key= 0
# Splitting data:   0%|▍                                                                                                                        | 1/256 [00:21<1:32:50, 21.84s/it]
# Saved fileNum= 0 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_0.npz
# Done saving files for file= 0
# Started key= 1
# Splitting data:   1%|▉                                                                                                                        | 2/256 [00:43<1:32:04, 21.75s/it]
# Saved fileNum= 1 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_1.npz
# Done saving files for file= 1
# Started key= 2
# Splitting data:   1%|█▍                                                                                                                       | 3/256 [01:05<1:32:03, 21.83s/it]
# Saved fileNum= 2 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_2.npz
# Done saving files for file= 2
# Started key= 3
# Splitting data:   2%|█▉                                                                                                                       | 4/256 [01:25<1:29:15, 21.25s/it]
# Saved fileNum= 3 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_3.npz
# Done saving files for file= 3
# Started key= 4
# Splitting data:   2%|██▎                                                                                                                      | 5/256 [01:46<1:27:45, 20.98s/it]
# Saved fileNum= 4 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_4.npz
# Done saving files for file= 4
# Started key= 5
# Splitting data:   2%|██▊                                                                                                                      | 6/256 [02:08<1:29:09, 21.40s/it]
# Saved fileNum= 5 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_5.npz
# Done saving files for file= 5
# Started key= 6
# Splitting data:   3%|███▎                                                                                                                     | 7/256 [02:28<1:27:23, 21.06s/it]
# Saved fileNum= 6 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_6.npz
# Done saving files for file= 6
# Started key= 7
# Splitting data:   3%|███▊                                                                                                                     | 8/256 [02:49<1:26:21, 20.89s/it]
# Saved fileNum= 7 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_7.npz
# Done saving files for file= 7
# Started key= 8
# Splitting data:   4%|████▎                                                                                                                    | 9/256 [03:11<1:27:11, 21.18s/it]
# Saved fileNum= 8 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_8.npz
# Done saving files for file= 8
# Started key= 9
# Splitting data:   4%|████▋                                                                                                                   | 10/256 [03:32<1:27:14, 21.28s/it]
# Saved fileNum= 9 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_9.npz
# Done saving files for file= 9
# Started key= 10
# Splitting data:   4%|█████▏                                                                                                                  | 11/256 [03:53<1:26:22, 21.15s/it]
# Saved fileNum= 10 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_10.npz
# Done saving files for file= 10
# Started key= 11
# Splitting data:   5%|█████▋                                                                                                                  | 12/256 [04:14<1:25:50, 21.11s/it]
# Saved fileNum= 11 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_11.npz
# Done saving files for file= 11
# Started key= 12
# Splitting data:   5%|██████                                                                                                                  | 13/256 [04:35<1:25:21, 21.08s/it]
# Saved fileNum= 12 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_12.npz
# Done saving files for file= 12
# Started key= 13
# Splitting data:   5%|██████▌                                                                                                                 | 14/256 [04:56<1:24:58, 21.07s/it]
# Saved fileNum= 13 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_13.npz
# Done saving files for file= 13
# Started key= 14
# Splitting data:   6%|███████                                                                                                                 | 15/256 [05:17<1:24:32, 21.05s/it]
# Saved fileNum= 14 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_14.npz
# Done saving files for file= 14
# Started key= 15
# Splitting data:   6%|███████▌                                                                                                                | 16/256 [05:38<1:24:15, 21.06s/it]
# Saved fileNum= 15 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_15.npz
# Done saving files for file= 15
# Started key= 16
# Splitting data:   7%|███████▉                                                                                                                | 17/256 [05:59<1:23:20, 20.92s/it]
# Saved fileNum= 16 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_16.npz
# Done saving files for file= 16
# Started key= 17
# Splitting data:   7%|████████▍                                                                                                               | 18/256 [06:20<1:22:48, 20.87s/it]
# Saved fileNum= 17 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_17.npz
# Done saving files for file= 17
# Started key= 18
# Splitting data:   7%|████████▉                                                                                                               | 19/256 [06:41<1:22:36, 20.91s/it]
# Saved fileNum= 18 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_18.npz
# Done saving files for file= 18
# Started key= 19
# Splitting data:   8%|█████████▍                                                                                                              | 20/256 [07:09<1:30:50, 23.10s/it]
# Saved fileNum= 19 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_19.npz
# Done saving files for file= 19
# Started key= 20
# Splitting data:   8%|█████████▊                                                                                                              | 21/256 [07:31<1:29:03, 22.74s/it]
# Saved fileNum= 20 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_20.npz
# Done saving files for file= 20
# Started key= 21
# Splitting data:   9%|██████████▎                                                                                                             | 22/256 [07:53<1:27:37, 22.47s/it]
# Saved fileNum= 21 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_21.npz
# Done saving files for file= 21
# Started key= 22
# Splitting data:   9%|██████████▊                                                                                                             | 23/256 [08:14<1:26:08, 22.18s/it]
# Saved fileNum= 22 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_22.npz
# Done saving files for file= 22
# Started key= 23
# Splitting data:   9%|███████████▎                                                                                                            | 24/256 [08:36<1:25:17, 22.06s/it]
# Saved fileNum= 23 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_23.npz
# Done saving files for file= 23
# Started key= 24
# Splitting data:  10%|███████████▋                                                                                                            | 25/256 [08:57<1:24:08, 21.85s/it]
# Saved fileNum= 24 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_24.npz
# Done saving files for file= 24
# Started key= 25
# Splitting data:  10%|████████████▏                                                                                                           | 26/256 [09:19<1:23:55, 21.89s/it]
# Saved fileNum= 25 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_25.npz
# Done saving files for file= 25
# Started key= 26
# Splitting data:  11%|████████████▋                                                                                                           | 27/256 [09:42<1:24:12, 22.06s/it]
# Saved fileNum= 26 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_26.npz
# Done saving files for file= 26
# Started key= 27
# Splitting data:  11%|█████████████▏                                                                                                          | 28/256 [10:03<1:23:30, 21.98s/it]
# Saved fileNum= 27 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_27.npz
# Done saving files for file= 27
# Started key= 28
# Splitting data:  11%|█████████████▌                                                                                                          | 29/256 [10:24<1:21:40, 21.59s/it]
# Saved fileNum= 28 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_28.npz
# Done saving files for file= 28
# Started key= 29
# Splitting data:  12%|██████████████                                                                                                          | 30/256 [10:49<1:25:13, 22.63s/it]
# Saved fileNum= 29 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_29.npz
# Done saving files for file= 29
# Started key= 30
# Splitting data:  12%|██████████████▌                                                                                                         | 31/256 [11:11<1:24:03, 22.42s/it]
# Saved fileNum= 30 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_30.npz
# Done saving files for file= 30
# Started key= 31
# Splitting data:  12%|███████████████                                                                                                         | 32/256 [11:33<1:23:22, 22.33s/it]
# Saved fileNum= 31 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_31.npz
# Done saving files for file= 31
# Started key= 32
# Splitting data:  13%|███████████████▍                                                                                                        | 33/256 [11:55<1:22:48, 22.28s/it]
# Saved fileNum= 32 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_32.npz
# Done saving files for file= 32
# Started key= 33
# Splitting data:  13%|███████████████▉                                                                                                        | 34/256 [12:18<1:22:36, 22.33s/it]
# Saved fileNum= 33 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_33.npz
# Done saving files for file= 33
# Started key= 34
# Splitting data:  14%|████████████████▍                                                                                                       | 35/256 [12:41<1:22:59, 22.53s/it]
# Saved fileNum= 34 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_34.npz
# Done saving files for file= 34
# Started key= 35
# Splitting data:  14%|████████████████▉                                                                                                       | 36/256 [13:05<1:24:38, 23.08s/it]
# Saved fileNum= 35 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_35.npz
# Done saving files for file= 35
# Started key= 36
# Splitting data:  14%|█████████████████▎                                                                                                      | 37/256 [13:29<1:24:47, 23.23s/it]
# Saved fileNum= 36 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_36.npz
# Done saving files for file= 36
# Started key= 37
# Splitting data:  15%|█████████████████▊                                                                                                      | 38/256 [13:53<1:25:33, 23.55s/it]
# Saved fileNum= 37 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_37.npz
# Done saving files for file= 37
# Started key= 38
# Splitting data:  15%|██████████████████▎                                                                                                     | 39/256 [14:18<1:26:32, 23.93s/it]
# Saved fileNum= 38 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_38.npz
# Done saving files for file= 38
# Started key= 39
# Splitting data:  16%|██████████████████▊                                                                                                     | 40/256 [14:42<1:26:19, 23.98s/it]
# Saved fileNum= 39 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_39.npz
# Done saving files for file= 39
# Started key= 40
# Splitting data:  16%|███████████████████▏                                                                                                    | 41/256 [15:05<1:24:44, 23.65s/it]
# Saved fileNum= 40 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_40.npz
# Done saving files for file= 40
# Started key= 41
# Splitting data:  16%|███████████████████▋                                                                                                    | 42/256 [15:33<1:29:30, 25.10s/it]
# Saved fileNum= 41 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_41.npz
# Done saving files for file= 41
# Started key= 42
# Splitting data:  17%|████████████████████▏                                                                                                   | 43/256 [15:56<1:26:43, 24.43s/it]
# Saved fileNum= 42 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_42.npz
# Done saving files for file= 42
# Started key= 43
# Splitting data:  17%|████████████████████▋                                                                                                   | 44/256 [16:19<1:24:18, 23.86s/it]
# Saved fileNum= 43 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_43.npz
# Done saving files for file= 43
# Started key= 44
# Splitting data:  18%|█████████████████████                                                                                                   | 45/256 [16:42<1:23:42, 23.80s/it]
# Saved fileNum= 44 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_44.npz
# Done saving files for file= 44
# Started key= 45
# Splitting data:  18%|█████████████████████▌                                                                                                  | 46/256 [17:06<1:23:27, 23.85s/it]
# Saved fileNum= 45 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_45.npz
# Done saving files for file= 45
# Started key= 46
# Splitting data:  18%|██████████████████████                                                                                                  | 47/256 [17:30<1:23:17, 23.91s/it]
# Saved fileNum= 46 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_46.npz
# Done saving files for file= 46
# Started key= 47
# Splitting data:  19%|██████████████████████▌                                                                                                 | 48/256 [17:54<1:22:39, 23.84s/it]
# Saved fileNum= 47 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_47.npz
# Done saving files for file= 47
# Started key= 48
# Splitting data:  19%|██████████████████████▉                                                                                                 | 49/256 [18:16<1:20:31, 23.34s/it]
# Saved fileNum= 48 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_48.npz
# Done saving files for file= 48
# Started key= 49
# Splitting data:  20%|███████████████████████▍                                                                                                | 50/256 [18:41<1:21:14, 23.66s/it]
# Saved fileNum= 49 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_49.npz
# Done saving files for file= 49
# Started key= 50
# Splitting data:  20%|███████████████████████▉                                                                                                | 51/256 [19:06<1:22:20, 24.10s/it]
# Saved fileNum= 50 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_50.npz
# Done saving files for file= 50
# Started key= 51
# Splitting data:  20%|████████████████████████▍                                                                                               | 52/256 [19:30<1:22:11, 24.17s/it]
# Saved fileNum= 51 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_51.npz
# Done saving files for file= 51
# Started key= 52
# Splitting data:  21%|████████████████████████▊                                                                                               | 53/256 [19:54<1:20:58, 23.94s/it]
# Saved fileNum= 52 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_52.npz
# Done saving files for file= 52
# Started key= 53
# Splitting data:  21%|█████████████████████████▎                                                                                              | 54/256 [20:18<1:20:40, 23.96s/it]
# Saved fileNum= 53 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_53.npz
# Done saving files for file= 53
# Started key= 54
# Splitting data:  21%|█████████████████████████▊                                                                                              | 55/256 [20:42<1:20:41, 24.09s/it]
# Saved fileNum= 54 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_54.npz
# Done saving files for file= 54
# Started key= 55
# Splitting data:  22%|██████████████████████████▎                                                                                             | 56/256 [21:05<1:19:31, 23.86s/it]
# Saved fileNum= 55 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_55.npz
# Done saving files for file= 55
# Started key= 56
# Splitting data:  22%|██████████████████████████▋                                                                                             | 57/256 [21:29<1:18:36, 23.70s/it]
# Saved fileNum= 56 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_56.npz
# Done saving files for file= 56
# Started key= 57
# Splitting data:  23%|███████████████████████████▏                                                                                            | 58/256 [21:52<1:18:04, 23.66s/it]
# Saved fileNum= 57 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_57.npz
# Done saving files for file= 57
# Started key= 58
# Splitting data:  23%|███████████████████████████▋                                                                                            | 59/256 [22:17<1:18:31, 23.92s/it]
# Saved fileNum= 58 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_58.npz
# Done saving files for file= 58
# Started key= 59
# Splitting data:  23%|████████████████████████████▏                                                                                           | 60/256 [22:41<1:18:38, 24.07s/it]
# Saved fileNum= 59 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_59.npz
# Done saving files for file= 59
# Started key= 60
# Splitting data:  24%|████████████████████████████▌                                                                                           | 61/256 [23:06<1:18:40, 24.21s/it]
# Saved fileNum= 60 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_60.npz
# Done saving files for file= 60
# Started key= 61
# Splitting data:  24%|█████████████████████████████                                                                                           | 62/256 [23:29<1:17:28, 23.96s/it]
# Saved fileNum= 61 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_61.npz
# Done saving files for file= 61
# Started key= 62
# Splitting data:  25%|█████████████████████████████▌                                                                                          | 63/256 [23:53<1:17:13, 24.01s/it]
# Saved fileNum= 62 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_62.npz
# Done saving files for file= 62
# Started key= 63
# Splitting data:  25%|██████████████████████████████                                                                                          | 64/256 [24:15<1:15:04, 23.46s/it]
# Saved fileNum= 63 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_63.npz
# Done saving files for file= 63
# Started key= 64
# Splitting data:  25%|██████████████████████████████▍                                                                                         | 65/256 [24:38<1:14:22, 23.36s/it]
# Saved fileNum= 64 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_64.npz
# Done saving files for file= 64
# Started key= 65
# Splitting data:  26%|██████████████████████████████▉                                                                                         | 66/256 [25:00<1:12:41, 22.96s/it]
# Saved fileNum= 65 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_65.npz
# Done saving files for file= 65
# Started key= 66
# Splitting data:  26%|███████████████████████████████▍                                                                                        | 67/256 [25:23<1:11:58, 22.85s/it]
# Saved fileNum= 66 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_66.npz
# Done saving files for file= 66
# Started key= 67
# Splitting data:  27%|███████████████████████████████▉                                                                                        | 68/256 [25:48<1:13:09, 23.35s/it]
# Saved fileNum= 67 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_67.npz
# Done saving files for file= 67
# Started key= 68
# Splitting data:  27%|████████████████████████████████▎                                                                                       | 69/256 [26:11<1:13:14, 23.50s/it]
# Saved fileNum= 68 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_68.npz
# Done saving files for file= 68
# Started key= 69
# Splitting data:  27%|████████████████████████████████▊                                                                                       | 70/256 [26:35<1:12:59, 23.54s/it]
# Saved fileNum= 69 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_69.npz
# Done saving files for file= 69
# Started key= 70
# Splitting data:  28%|█████████████████████████████████▎                                                                                      | 71/256 [26:58<1:12:04, 23.38s/it]
# Saved fileNum= 70 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_70.npz
# Done saving files for file= 70
# Started key= 71
# Splitting data:  28%|█████████████████████████████████▊                                                                                      | 72/256 [27:21<1:11:43, 23.39s/it]
# Saved fileNum= 71 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_71.npz
# Done saving files for file= 71
# Started key= 72
# Splitting data:  29%|██████████████████████████████████▏                                                                                     | 73/256 [27:46<1:12:21, 23.73s/it]
# Saved fileNum= 72 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_72.npz
# Done saving files for file= 72
# Started key= 73
# Splitting data:  29%|██████████████████████████████████▋                                                                                     | 74/256 [28:10<1:11:52, 23.69s/it]
# Saved fileNum= 73 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_73.npz
# Done saving files for file= 73
# Started key= 74
# Splitting data:  29%|███████████████████████████████████▏                                                                                    | 75/256 [28:32<1:10:34, 23.40s/it]
# Saved fileNum= 74 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_74.npz
# Done saving files for file= 74
# Started key= 75
# Splitting data:  30%|███████████████████████████████████▋                                                                                    | 76/256 [28:56<1:10:12, 23.40s/it]
# Saved fileNum= 75 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_75.npz
# Done saving files for file= 75
# Started key= 76
# Splitting data:  30%|████████████████████████████████████                                                                                    | 77/256 [29:19<1:09:50, 23.41s/it]
# Saved fileNum= 76 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_76.npz
# Done saving files for file= 76
# Started key= 77
# Splitting data:  30%|████████████████████████████████████▌                                                                                   | 78/256 [29:42<1:08:41, 23.16s/it]
# Saved fileNum= 77 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_77.npz
# Done saving files for file= 77
# Started key= 78
# Splitting data:  31%|█████████████████████████████████████                                                                                   | 79/256 [30:05<1:08:25, 23.20s/it]
# Saved fileNum= 78 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_78.npz
# Done saving files for file= 78
# Started key= 79
# Splitting data:  31%|█████████████████████████████████████▌                                                                                  | 80/256 [30:28<1:08:17, 23.28s/it]
# Saved fileNum= 79 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_79.npz
# Done saving files for file= 79
# Started key= 80
# Splitting data:  32%|█████████████████████████████████████▉                                                                                  | 81/256 [30:51<1:07:20, 23.09s/it]
# Saved fileNum= 80 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_80.npz
# Done saving files for file= 80
# Started key= 81
# Splitting data:  32%|██████████████████████████████████████▍                                                                                 | 82/256 [31:15<1:07:38, 23.33s/it]
# Saved fileNum= 81 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_81.npz
# Done saving files for file= 81
# Started key= 82
# Splitting data:  32%|██████████████████████████████████████▉                                                                                 | 83/256 [31:38<1:06:44, 23.15s/it]
# Saved fileNum= 82 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_82.npz
# Done saving files for file= 82
# Started key= 83
# Splitting data:  33%|███████████████████████████████████████▍                                                                                | 84/256 [32:01<1:06:08, 23.07s/it]
# Saved fileNum= 83 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_83.npz
# Done saving files for file= 83
# Started key= 84
# Splitting data:  33%|███████████████████████████████████████▊                                                                                | 85/256 [32:25<1:06:35, 23.36s/it]
# Saved fileNum= 84 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_84.npz
# Done saving files for file= 84
# Started key= 85
# Splitting data:  34%|████████████████████████████████████████▎                                                                               | 86/256 [32:48<1:06:28, 23.46s/it]
# Saved fileNum= 85 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_85.npz
# Done saving files for file= 85
# Started key= 86
# Splitting data:  34%|████████████████████████████████████████▊                                                                               | 87/256 [33:13<1:07:08, 23.84s/it]
# Saved fileNum= 86 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_86.npz
# Done saving files for file= 86
# Started key= 87
# Splitting data:  34%|█████████████████████████████████████████▎                                                                              | 88/256 [33:37<1:06:41, 23.82s/it]
# Saved fileNum= 87 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_87.npz
# Done saving files for file= 87
# Started key= 88
# Splitting data:  35%|█████████████████████████████████████████▋                                                                              | 89/256 [33:59<1:04:55, 23.33s/it]
# Saved fileNum= 88 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_88.npz
# Done saving files for file= 88
# Started key= 89
# Splitting data:  35%|██████████████████████████████████████████▏                                                                             | 90/256 [34:22<1:04:01, 23.14s/it]
# Saved fileNum= 89 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_89.npz
# Done saving files for file= 89
# Started key= 90
# Splitting data:  36%|██████████████████████████████████████████▋                                                                             | 91/256 [34:46<1:04:34, 23.48s/it]
# Saved fileNum= 90 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_90.npz
# Done saving files for file= 90
# Started key= 91
# Splitting data:  36%|███████████████████████████████████████████▏                                                                            | 92/256 [35:10<1:04:40, 23.66s/it]
# Saved fileNum= 91 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_91.npz
# Done saving files for file= 91
# Started key= 92
# Splitting data:  36%|███████████████████████████████████████████▌                                                                            | 93/256 [35:34<1:04:46, 23.84s/it]
# Saved fileNum= 92 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_92.npz
# Done saving files for file= 92
# Started key= 93
# Splitting data:  37%|████████████████████████████████████████████                                                                            | 94/256 [35:57<1:03:21, 23.46s/it]
# Saved fileNum= 93 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_93.npz
# Done saving files for file= 93
# Started key= 94
# Splitting data:  37%|████████████████████████████████████████████▌                                                                           | 95/256 [36:19<1:01:41, 22.99s/it]
# Saved fileNum= 94 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_94.npz
# Done saving files for file= 94
# Started key= 95
# Splitting data:  38%|█████████████████████████████████████████████                                                                           | 96/256 [36:42<1:01:40, 23.13s/it]
# Saved fileNum= 95 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_95.npz
# Done saving files for file= 95
# Started key= 96
# Splitting data:  38%|█████████████████████████████████████████████▍                                                                          | 97/256 [37:06<1:01:37, 23.26s/it]
# Saved fileNum= 96 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_96.npz
# Done saving files for file= 96
# Started key= 97
# Splitting data:  38%|█████████████████████████████████████████████▉                                                                          | 98/256 [37:28<1:00:34, 23.00s/it]
# Saved fileNum= 97 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_97.npz
# Done saving files for file= 97
# Started key= 98
# Splitting data:  39%|███████████████████████████████████████████████▏                                                                          | 99/256 [37:50<59:26, 22.72s/it]
# Saved fileNum= 98 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_98.npz
# Done saving files for file= 98
# Started key= 99
# Splitting data:  39%|██████████████████████████████████████████████▍                                                                        | 100/256 [38:15<1:00:43, 23.36s/it]
# Saved fileNum= 99 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_99.npz
# Done saving files for file= 99
# Started key= 100
# Splitting data:  39%|██████████████████████████████████████████████▉                                                                        | 101/256 [38:39<1:00:48, 23.54s/it]
# Saved fileNum= 100 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_100.npz
# Done saving files for file= 100
# Started key= 101
# Splitting data:  40%|███████████████████████████████████████████████▍                                                                       | 102/256 [39:03<1:00:26, 23.55s/it]
# Saved fileNum= 101 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_101.npz
# Done saving files for file= 101
# Started key= 102
# Splitting data:  40%|███████████████████████████████████████████████▉                                                                       | 103/256 [39:26<1:00:12, 23.61s/it]
# Saved fileNum= 102 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_102.npz
# Done saving files for file= 102
# Started key= 103
# Splitting data:  41%|████████████████████████████████████████████████▎                                                                      | 104/256 [39:51<1:00:38, 23.94s/it]
# Saved fileNum= 103 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_103.npz
# Done saving files for file= 103
# Started key= 104
# Splitting data:  41%|████████████████████████████████████████████████▊                                                                      | 105/256 [40:15<1:00:26, 24.02s/it]
# Saved fileNum= 104 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_104.npz
# Done saving files for file= 104
# Started key= 105
# Splitting data:  41%|█████████████████████████████████████████████████▎                                                                     | 106/256 [40:42<1:02:14, 24.89s/it]
# Saved fileNum= 105 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_105.npz
# Done saving files for file= 105
# Started key= 106
# Splitting data:  42%|█████████████████████████████████████████████████▋                                                                     | 107/256 [41:07<1:01:21, 24.71s/it]
# Saved fileNum= 106 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_106.npz
# Done saving files for file= 106
# Started key= 107
# Splitting data:  42%|███████████████████████████████████████████████████                                                                      | 108/256 [41:30<59:54, 24.29s/it]
# Saved fileNum= 107 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_107.npz
# Done saving files for file= 107
# Started key= 108
# Splitting data:  43%|███████████████████████████████████████████████████▌                                                                     | 109/256 [41:52<57:58, 23.66s/it]
# Saved fileNum= 108 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_108.npz
# Done saving files for file= 108
# Started key= 109
# Splitting data:  43%|███████████████████████████████████████████████████▉                                                                     | 110/256 [42:15<56:57, 23.41s/it]
# Saved fileNum= 109 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_109.npz
# Done saving files for file= 109
# Started key= 110
# Splitting data:  43%|████████████████████████████████████████████████████▍                                                                    | 111/256 [42:38<56:17, 23.29s/it]
# Saved fileNum= 110 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_110.npz
# Done saving files for file= 110
# Started key= 111
# Splitting data:  44%|████████████████████████████████████████████████████▉                                                                    | 112/256 [43:01<55:58, 23.32s/it]
# Saved fileNum= 111 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_111.npz
# Done saving files for file= 111
# Started key= 112
# Splitting data:  44%|█████████████████████████████████████████████████████▍                                                                   | 113/256 [43:25<55:29, 23.28s/it]
# Saved fileNum= 112 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_112.npz
# Done saving files for file= 112
# Started key= 113
# Splitting data:  45%|█████████████████████████████████████████████████████▉                                                                   | 114/256 [43:49<56:15, 23.77s/it]
# Saved fileNum= 113 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_113.npz
# Done saving files for file= 113
# Started key= 114
# Splitting data:  45%|██████████████████████████████████████████████████████▎                                                                  | 115/256 [44:14<56:31, 24.05s/it]
# Saved fileNum= 114 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_114.npz
# Done saving files for file= 114
# Started key= 115
# Splitting data:  45%|██████████████████████████████████████████████████████▊                                                                  | 116/256 [44:38<56:06, 24.05s/it]
# Saved fileNum= 115 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_115.npz
# Done saving files for file= 115
# Started key= 116
# Splitting data:  46%|███████████████████████████████████████████████████████▎                                                                 | 117/256 [45:02<55:17, 23.87s/it]
# Saved fileNum= 116 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_116.npz
# Done saving files for file= 116
# Started key= 117
# Splitting data:  46%|███████████████████████████████████████████████████████▊                                                                 | 118/256 [45:25<54:20, 23.63s/it]
# Saved fileNum= 117 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_117.npz
# Done saving files for file= 117
# Started key= 118
# Splitting data:  46%|████████████████████████████████████████████████████████▏                                                                | 119/256 [45:48<53:51, 23.59s/it]
# Saved fileNum= 118 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_118.npz
# Done saving files for file= 118
# Started key= 119
# Splitting data:  47%|████████████████████████████████████████████████████████▋                                                                | 120/256 [46:13<54:29, 24.04s/it]
# Saved fileNum= 119 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_119.npz
# Done saving files for file= 119
# Started key= 120
# Splitting data:  47%|█████████████████████████████████████████████████████████▏                                                               | 121/256 [46:38<54:29, 24.22s/it]
# Saved fileNum= 120 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_120.npz
# Done saving files for file= 120
# Started key= 121
# Splitting data:  48%|█████████████████████████████████████████████████████████▋                                                               | 122/256 [47:02<53:47, 24.09s/it]
# Saved fileNum= 121 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_121.npz
# Done saving files for file= 121
# Started key= 122
# Splitting data:  48%|██████████████████████████████████████████████████████████▏                                                              | 123/256 [47:24<52:08, 23.53s/it]
# Saved fileNum= 122 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_122.npz
# Done saving files for file= 122
# Started key= 123
# Splitting data:  48%|██████████████████████████████████████████████████████████▌                                                              | 124/256 [47:46<50:40, 23.03s/it]
# Saved fileNum= 123 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_123.npz
# Done saving files for file= 123
# Started key= 124
# Splitting data:  49%|███████████████████████████████████████████████████████████                                                              | 125/256 [48:08<50:01, 22.91s/it]
# Saved fileNum= 124 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_124.npz
# Done saving files for file= 124
# Started key= 125
# Splitting data:  49%|███████████████████████████████████████████████████████████▌                                                             | 126/256 [48:32<50:02, 23.10s/it]
# Saved fileNum= 125 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_125.npz
# Done saving files for file= 125
# Started key= 126
# Splitting data:  50%|████████████████████████████████████████████████████████████                                                             | 127/256 [48:56<50:06, 23.31s/it]
# Saved fileNum= 126 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_126.npz
# Done saving files for file= 126
# Started key= 127
# Splitting data:  50%|████████████████████████████████████████████████████████████▌                                                            | 128/256 [49:19<49:33, 23.23s/it]
# Saved fileNum= 127 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_127.npz
# Done saving files for file= 127
# Started key= 128
# Splitting data:  50%|████████████████████████████████████████████████████████████▉                                                            | 129/256 [49:41<48:38, 22.98s/it]
# Saved fileNum= 128 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_128.npz
# Done saving files for file= 128
# Started key= 129
# Splitting data:  51%|█████████████████████████████████████████████████████████████▍                                                           | 130/256 [50:06<49:12, 23.43s/it]
# Saved fileNum= 129 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_129.npz
# Done saving files for file= 129
# Started key= 130
# Splitting data:  51%|█████████████████████████████████████████████████████████████▉                                                           | 131/256 [50:28<48:00, 23.04s/it]
# Saved fileNum= 130 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_130.npz
# Done saving files for file= 130
# Started key= 131
# Splitting data:  52%|██████████████████████████████████████████████████████████████▍                                                          | 132/256 [50:50<46:49, 22.65s/it]
# Saved fileNum= 131 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_131.npz
# Done saving files for file= 131
# Started key= 132
# Splitting data:  52%|██████████████████████████████████████████████████████████████▊                                                          | 133/256 [51:13<47:10, 23.01s/it]
# Saved fileNum= 132 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_132.npz
# Done saving files for file= 132
# Started key= 133
# Splitting data:  52%|███████████████████████████████████████████████████████████████▎                                                         | 134/256 [51:36<46:33, 22.90s/it]
# Saved fileNum= 133 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_133.npz
# Done saving files for file= 133
# Started key= 134
# Splitting data:  53%|███████████████████████████████████████████████████████████████▊                                                         | 135/256 [52:00<46:31, 23.07s/it]
# Saved fileNum= 134 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_134.npz
# Done saving files for file= 134
# Started key= 135
# Splitting data:  53%|████████████████████████████████████████████████████████████████▎                                                        | 136/256 [52:23<46:35, 23.30s/it]
# Saved fileNum= 135 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_135.npz
# Done saving files for file= 135
# Started key= 136
# Splitting data:  54%|████████████████████████████████████████████████████████████████▊                                                        | 137/256 [52:47<46:14, 23.31s/it]
# Saved fileNum= 136 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_136.npz
# Done saving files for file= 136
# Started key= 137
# Splitting data:  54%|█████████████████████████████████████████████████████████████████▏                                                       | 138/256 [53:10<46:05, 23.43s/it]
# Saved fileNum= 137 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_137.npz
# Done saving files for file= 137
# Started key= 138
# Splitting data:  54%|█████████████████████████████████████████████████████████████████▋                                                       | 139/256 [53:33<45:25, 23.30s/it]
# Saved fileNum= 138 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_138.npz
# Done saving files for file= 138
# Started key= 139
# Splitting data:  55%|██████████████████████████████████████████████████████████████████▏                                                      | 140/256 [53:56<44:44, 23.15s/it]
# Saved fileNum= 139 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_139.npz
# Done saving files for file= 139
# Started key= 140
# Splitting data:  55%|██████████████████████████████████████████████████████████████████▋                                                      | 141/256 [54:20<44:46, 23.36s/it]
# Saved fileNum= 140 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_140.npz
# Done saving files for file= 140
# Started key= 141
# Splitting data:  55%|███████████████████████████████████████████████████████████████████                                                      | 142/256 [54:45<45:35, 23.99s/it]
# Saved fileNum= 141 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_141.npz
# Done saving files for file= 141
# Started key= 142
# Splitting data:  56%|███████████████████████████████████████████████████████████████████▌                                                     | 143/256 [55:08<44:30, 23.64s/it]
# Saved fileNum= 142 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_142.npz
# Done saving files for file= 142
# Started key= 143
# Splitting data:  56%|████████████████████████████████████████████████████████████████████                                                     | 144/256 [55:31<43:20, 23.22s/it]
# Saved fileNum= 143 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_143.npz
# Done saving files for file= 143
# Started key= 144
# Splitting data:  57%|████████████████████████████████████████████████████████████████████▌                                                    | 145/256 [55:54<43:14, 23.37s/it]
# Saved fileNum= 144 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_144.npz
# Done saving files for file= 144
# Started key= 145
# Splitting data:  57%|█████████████████████████████████████████████████████████████████████                                                    | 146/256 [56:18<42:48, 23.35s/it]
# Saved fileNum= 145 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_145.npz
# Done saving files for file= 145
# Started key= 146
# Splitting data:  57%|█████████████████████████████████████████████████████████████████████▍                                                   | 147/256 [56:41<42:34, 23.43s/it]
# Saved fileNum= 146 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_146.npz
# Done saving files for file= 146
# Started key= 147
# Splitting data:  58%|█████████████████████████████████████████████████████████████████████▉                                                   | 148/256 [57:06<43:05, 23.94s/it]
# Saved fileNum= 147 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_147.npz
# Done saving files for file= 147
# Started key= 148
# Splitting data:  58%|██████████████████████████████████████████████████████████████████████▍                                                  | 149/256 [57:30<42:20, 23.75s/it]
# Saved fileNum= 148 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_148.npz
# Done saving files for file= 148
# Started key= 149
# Splitting data:  59%|██████████████████████████████████████████████████████████████████████▉                                                  | 150/256 [57:53<41:37, 23.56s/it]
# Saved fileNum= 149 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_149.npz
# Done saving files for file= 149
# Started key= 150
# Splitting data:  59%|███████████████████████████████████████████████████████████████████████▎                                                 | 151/256 [58:17<41:23, 23.65s/it]
# Saved fileNum= 150 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_150.npz
# Done saving files for file= 150
# Started key= 151
# Splitting data:  59%|███████████████████████████████████████████████████████████████████████▊                                                 | 152/256 [58:41<41:15, 23.81s/it]
# Saved fileNum= 151 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_151.npz
# Done saving files for file= 151
# Started key= 152
# Splitting data:  60%|████████████████████████████████████████████████████████████████████████▎                                                | 153/256 [59:05<40:56, 23.85s/it]
# Saved fileNum= 152 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_152.npz
# Done saving files for file= 152
# Started key= 153
# Splitting data:  60%|████████████████████████████████████████████████████████████████████████▊                                                | 154/256 [59:29<40:34, 23.86s/it]
# Saved fileNum= 153 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_153.npz
# Done saving files for file= 153
# Started key= 154
# Splitting data:  61%|█████████████████████████████████████████████████████████████████████████▎                                               | 155/256 [59:52<40:10, 23.87s/it]
# Saved fileNum= 154 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_154.npz
# Done saving files for file= 154
# Started key= 155
# Splitting data:  61%|████████████████████████████████████████████████████████████████████████▌                                              | 156/256 [1:00:15<39:19, 23.60s/it]
# Saved fileNum= 155 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_155.npz
# Done saving files for file= 155
# Started key= 156
# Splitting data:  61%|████████████████████████████████████████████████████████████████████████▉                                              | 157/256 [1:00:40<39:13, 23.77s/it]
# ...
# Saved fileNum= 204 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_204.npz
# Done saving files for file= 204
# Started key= 205
# Splitting data:  80%|███████████████████████████████████████████████████████████████████████████████████████████████▊                       | 206/256 [1:19:41<19:29, 23.40s/it]
# Saved fileNum= 205 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_205.npz
# Done saving files for file= 205
# Started key= 206
# Splitting data:  81%|████████████████████████████████████████████████████████████████████████████████████████████████▏                      | 207/256 [1:20:04<19:11, 23.49s/it]
# Saved fileNum= 206 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_206.npz
# Done saving files for file= 206
# Started key= 207
# Splitting data:  81%|████████████████████████████████████████████████████████████████████████████████████████████████▋                      | 208/256 [1:20:26<18:21, 22.96s/it]
# Saved fileNum= 207 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_207.npz
# Done saving files for file= 207
# Started key= 208
# Splitting data:  82%|█████████████████████████████████████████████████████████████████████████████████████████████████▏                     | 209/256 [1:20:49<18:03, 23.06s/it]
# Saved fileNum= 208 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_208.npz
# Done saving files for file= 208
# Started key= 209
# Splitting data:  82%|█████████████████████████████████████████████████████████████████████████████████████████████████▌                     | 210/256 [1:21:12<17:37, 23.00s/it]
# Saved fileNum= 209 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_209.npz
# Done saving files for file= 209
# Started key= 210
# Splitting data:  82%|██████████████████████████████████████████████████████████████████████████████████████████████████                     | 211/256 [1:21:35<17:16, 23.04s/it]
# Saved fileNum= 210 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_210.npz
# Done saving files for file= 210
# Started key= 211
# Splitting data:  83%|██████████████████████████████████████████████████████████████████████████████████████████████████▌                    | 212/256 [1:21:59<16:59, 23.17s/it]
# Saved fileNum= 211 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_211.npz
# Done saving files for file= 211
# Started key= 212
# Splitting data:  83%|███████████████████████████████████████████████████████████████████████████████████████████████████                    | 213/256 [1:22:23<16:49, 23.48s/it]
# Saved fileNum= 212 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_212.npz
# Done saving files for file= 212
# Started key= 213
# Splitting data:  84%|███████████████████████████████████████████████████████████████████████████████████████████████████▍                   | 214/256 [1:22:48<16:45, 23.94s/it]
# Saved fileNum= 213 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_213.npz
# Done saving files for file= 213
# Started key= 214
# Splitting data:  84%|███████████████████████████████████████████████████████████████████████████████████████████████████▉                   | 215/256 [1:23:12<16:26, 24.07s/it]
# Saved fileNum= 214 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_214.npz
# Done saving files for file= 214
# Started key= 215
# Splitting data:  84%|████████████████████████████████████████████████████████████████████████████████████████████████████▍                  | 216/256 [1:23:35<15:44, 23.62s/it]
# Saved fileNum= 215 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_215.npz
# Done saving files for file= 215
# Started key= 216
# Splitting data:  85%|████████████████████████████████████████████████████████████████████████████████████████████████████▊                  | 217/256 [1:23:57<15:07, 23.27s/it]
# Saved fileNum= 216 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_216.npz
# Done saving files for file= 216
# Started key= 217
# Splitting data:  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████▎                 | 218/256 [1:24:20<14:35, 23.05s/it]
# Saved fileNum= 217 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_217.npz
# Done saving files for file= 217
# Started key= 218
# Splitting data:  86%|█████████████████████████████████████████████████████████████████████████████████████████████████████▊                 | 219/256 [1:24:45<14:31, 23.55s/it]
# Saved fileNum= 218 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_218.npz
# Done saving files for file= 218
# Started key= 219
# Splitting data:  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████▎                | 220/256 [1:25:09<14:16, 23.79s/it]
# Saved fileNum= 219 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_219.npz
# Done saving files for file= 219
# Started key= 220
# Splitting data:  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████▋                | 221/256 [1:25:31<13:35, 23.30s/it]
# Saved fileNum= 220 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_220.npz
# Done saving files for file= 220
# Started key= 221
# Splitting data:  87%|███████████████████████████████████████████████████████████████████████████████████████████████████████▏               | 222/256 [1:25:53<13:03, 23.04s/it]
# Saved fileNum= 221 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_221.npz
# Done saving files for file= 221
# Started key= 222
# Splitting data:  87%|███████████████████████████████████████████████████████████████████████████████████████████████████████▋               | 223/256 [1:26:16<12:37, 22.95s/it]
# Saved fileNum= 222 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_222.npz
# Done saving files for file= 222
# Started key= 223
# Splitting data:  88%|████████████████████████████████████████████████████████████████████████████████████████████████████████▏              | 224/256 [1:26:41<12:27, 23.35s/it]
# Saved fileNum= 223 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_223.npz
# Done saving files for file= 223
# Started key= 224
# Splitting data:  88%|████████████████████████████████████████████████████████████████████████████████████████████████████████▌              | 225/256 [1:27:04<12:05, 23.39s/it]
# Saved fileNum= 224 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_224.npz
# Done saving files for file= 224
# Started key= 225
# Splitting data:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████████████              | 226/256 [1:27:26<11:33, 23.10s/it]
# Saved fileNum= 225 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_225.npz
# Done saving files for file= 225
# Started key= 226
# Splitting data:  89%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▌             | 227/256 [1:27:50<11:15, 23.28s/it]
# Saved fileNum= 226 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_226.npz
# Done saving files for file= 226
# Started key= 227
# Splitting data:  89%|█████████████████████████████████████████████████████████████████████████████████████████████████████████▉             | 228/256 [1:28:15<11:01, 23.64s/it]
# Saved fileNum= 227 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_227.npz
# Done saving files for file= 227
# Started key= 228
# Splitting data:  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▍            | 229/256 [1:28:39<10:44, 23.88s/it]
# Saved fileNum= 228 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_228.npz
# Done saving files for file= 228
# Started key= 229
# Splitting data:  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▉            | 230/256 [1:29:02<10:13, 23.59s/it]
# Saved fileNum= 229 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_229.npz
# Done saving files for file= 229
# Started key= 230
# Splitting data:  90%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▍           | 231/256 [1:29:24<09:37, 23.12s/it]
# Saved fileNum= 230 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_230.npz
# Done saving files for file= 230
# Started key= 231
# Splitting data:  91%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▊           | 232/256 [1:29:47<09:16, 23.18s/it]
# Saved fileNum= 231 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_231.npz
# Done saving files for file= 231
# Started key= 232
# Splitting data:  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▎          | 233/256 [1:30:10<08:49, 23.03s/it]
# Saved fileNum= 232 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_232.npz
# Done saving files for file= 232
# Started key= 233
# Splitting data:  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▊          | 234/256 [1:30:32<08:22, 22.83s/it]
# Saved fileNum= 233 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_233.npz
# Done saving files for file= 233
# Started key= 234
# Splitting data:  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▏         | 235/256 [1:30:54<07:54, 22.61s/it]
# Saved fileNum= 234 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_234.npz
# Done saving files for file= 234
# Started key= 235
# Splitting data:  92%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▋         | 236/256 [1:31:15<07:22, 22.14s/it]
# Saved fileNum= 235 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_235.npz
# Done saving files for file= 235
# Started key= 236
# Splitting data:  93%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▏        | 237/256 [1:31:37<06:58, 22.01s/it]
# Saved fileNum= 236 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_236.npz
# Done saving files for file= 236
# Started key= 237
# Splitting data:  93%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▋        | 238/256 [1:32:00<06:38, 22.13s/it]
# Saved fileNum= 237 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_237.npz
# Done saving files for file= 237
# Started key= 238
# Splitting data:  93%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████        | 239/256 [1:32:21<06:13, 21.95s/it]
# Saved fileNum= 238 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_238.npz
# Done saving files for file= 238
# Started key= 239
# Splitting data:  94%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▌       | 240/256 [1:32:44<05:53, 22.08s/it]
# Saved fileNum= 239 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_239.npz
# Done saving files for file= 239
# Started key= 240
# Splitting data:  94%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████       | 241/256 [1:33:07<05:35, 22.40s/it]
# Saved fileNum= 240 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_240.npz
# Done saving files for file= 240
# Started key= 241
# Splitting data:  95%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍      | 242/256 [1:33:29<05:12, 22.31s/it]
# Saved fileNum= 241 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_241.npz
# Done saving files for file= 241
# Started key= 242
# Splitting data:  95%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉      | 243/256 [1:33:50<04:46, 22.00s/it]
# Saved fileNum= 242 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_242.npz
# Done saving files for file= 242
# Started key= 243
# Splitting data:  95%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍     | 244/256 [1:34:12<04:24, 22.04s/it]
# Saved fileNum= 243 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_243.npz
# Done saving files for file= 243
# Started key= 244
# Splitting data:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉     | 245/256 [1:34:34<04:01, 21.97s/it]
# Saved fileNum= 244 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_244.npz
# Done saving files for file= 244
# Started key= 245
# Splitting data:  96%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎    | 246/256 [1:34:57<03:41, 22.14s/it]
# Saved fileNum= 245 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_245.npz
# Done saving files for file= 245
# Started key= 246
# Splitting data:  96%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊    | 247/256 [1:35:20<03:23, 22.63s/it]
# Saved fileNum= 246 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_246.npz
# Done saving files for file= 246
# Started key= 247
# Splitting data:  97%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎   | 248/256 [1:35:43<03:01, 22.73s/it]
# Saved fileNum= 247 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_247.npz
# Done saving files for file= 247
# Started key= 248
# Splitting data:  97%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋   | 249/256 [1:36:06<02:39, 22.76s/it]
# Saved fileNum= 248 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_248.npz
# Done saving files for file= 248
# Started key= 249
# Splitting data:  98%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏  | 250/256 [1:36:29<02:16, 22.76s/it]
# Saved fileNum= 249 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_249.npz
# Done saving files for file= 249
# Started key= 250
# Splitting data:  98%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋  | 251/256 [1:36:52<01:54, 22.82s/it]
# Saved fileNum= 250 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_250.npz
# Done saving files for file= 250
# Started key= 251
# Splitting data:  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 252/256 [1:37:16<01:32, 23.11s/it]
# Saved fileNum= 251 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_251.npz
# Done saving files for file= 251
# Started key= 252
# Splitting data:  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌ | 253/256 [1:37:39<01:09, 23.29s/it]
# Saved fileNum= 252 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_252.npz
# Done saving files for file= 252
# Started key= 253
# Splitting data:  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████ | 254/256 [1:38:02<00:46, 23.12s/it]
# Saved fileNum= 253 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_253.npz
# Done saving files for file= 253
# Started key= 254
# Splitting data: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌| 255/256 [1:38:25<00:23, 23.00s/it]
# Saved fileNum= 254 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_254.npz
# Done saving files for file= 254
# Started key= 255
# Splitting data: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 256/256 [1:38:49<00:00, 23.16s/it]
# Saved fileNum= 255 to /mnt/hgfs/trace_key_l443_1500_15kAdd_dataset//train_255.npz
# Done saving files for file= 255
# Done saving all the traces

# %%
from tqdm import tnrange, trange
import chipwhisperer as cw
import pandas as pd
import os
import numpy as np

## dataFrame to store all the traces
df_new = pd.DataFrame(columns=['trace', 'key'])
traceList = []
keyList = []

trainSize= 7500
devSize = 500
testSize = 500
# ##Adding traces for not complete 
# keysNotDone = [204, 228, 244, 245]
# count = 0
prjDir = "/mnt/hgfs/trace_key_f303_tinyAES/"
saveDir = "/mnt/hgfs/compressed_dataset/"

fileNume=50
prjName = "file_" + str(fileNum)
new_project = cw.open_project(prjDir + prjName + ".cwp")
trace = new_project.traces

keylist=[]
for idx, traces in enumerate(trace):
    keyList.append(traces.key)

# %%
import collections
#ounter = collections.Counter(np.array(keyList)[:,0])
#counter
collection = collections.Counter(df_new.key.apply(lambda x: x[0]))
collection

# %%
scope.dis()
target.dis()

# %%
#ktp.fixed_key =False
ktp.next()
