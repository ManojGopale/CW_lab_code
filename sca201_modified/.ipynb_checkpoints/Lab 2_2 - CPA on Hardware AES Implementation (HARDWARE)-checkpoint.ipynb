# %% [markdown]
# # Topic 2, Part 2 - CPA on Hardware AES Implementation

# %% [markdown]
# ---
# NOTE: This lab references some (commercial) training material on [ChipWhisperer.io](https://www.ChipWhisperer.io). You can freely execute and use the lab per the open-source license (including using it in your own courses if you distribute similarly), but you must maintain notice about this source location. Consider joining our training course to enjoy the full experience.
#
# ---

# %% [markdown]
# Capture traces as normal. We'll need to select the HWAES crypto target instead of TINYAES or MBEDTLS. Also we don't need to capture as many traces - the whole AES block will fit in less than 2000 traces. We'll also boost the gain a little bit - HWAES won't result in as big of power spikes:

# %%
#SCOPETYPE = 'OPENADC'
#PLATFORM = 'CW308_STM32F4'
#CRYPTO_TARGET = 'HWAES'

# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CW308_STM32L4'
CRYPTO_TARGET = 'HWAES'
VERSION='HARDWARE'
SS_VER='SS_VER_2_0'

# %%
# %run "../../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /tmp/ipykernel_28896/2799263322.py:4
#       3 try:
# ----> 4     if not scope.connectStatus:
#       5         scope.con()
#
# NameError: name 'scope' is not defined
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# File /tmp/ipykernel_28896/2799263322.py:7
#       5         scope.con()
#       6 except NameError:
# ----> 7     scope = cw.scope()
#       9 try:
#      10     if SS_VER == "SS_VER_2_1":
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/__init__.py:383, in scope(scope_type, name, sn, idProduct, bitstream, force, prog_speed, **kwargs)
#     380         raise ValueError
#     382 if scope_type is None:
# --> 383     scope_type = get_cw_type(**kwargs)
#     384 rtn : scopes.ScopeTypes = scope_type()
#     385 try:
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/common/utils/util.py:522, in get_cw_type(sn, idProduct, hw_location, **kwargs)
#     519     possible_ids = [0xace0, 0xace2, 0xace3, 0xace5]
#     521 cwusb = NAEUSB_Backend()
# --> 522 device = cwusb.find(serial_number=sn, idProduct=possible_ids, hw_location=hw_location)
#     523 name = device.getProduct()
#     524 cwusb.usb_ctx.close()
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:366, in NAEUSB_Backend.find(self, serial_number, idProduct, hw_location)
#     363 def find(self, serial_number : Optional[str]=None, idProduct : Optional[List[int]]=None,
#     364     hw_location : Optional[Tuple[int, int]]=None) -> usb1.USBDevice:
#     365     # check if we got anything
# --> 366     dev_list = self.get_possible_devices(idProduct, attempt_access=(not hw_location))
#     367     if len(dev_list) == 0:
#     368         raise OSError("Could not find ChipWhisperer. Is it connected?")
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:490, in NAEUSB_Backend.get_possible_devices(self, idProduct, dictonly, attempt_access)
#     487                 dev_list.remove(dev)
#     489         if len(dev_list) == 0:
# --> 490             raise OSError("Unable to communicate with found ChipWhisperer. Check that \
#     491 \nanother process isn't connected to it and that you have permission to communicate with it.")
#     493         return dev_list
#
# OSError: Unable to communicate with found ChipWhisperer. Check that
# another process isn't connected to it and that you have permission to communicate with it.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /tmp/ipykernel_28896/2799263322.py:4
#       3 try:
# ----> 4     if not scope.connectStatus:
#       5         scope.con()
#
# NameError: name 'scope' is not defined
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('run', '"../../Setup_Scripts/Setup_Generic.ipynb"')
#
# File ~/.pyenv/versions/cw/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.pyenv/versions/cw/lib/python3.9/site-packages/IPython/core/magics/execution.py:722, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     720     with preserve_keys(self.shell.user_ns, '__file__'):
#     721         self.shell.user_ns['__file__'] = filename
# --> 722         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     723     return
#     725 # Control the response to exit() calls made by the script being run
#
# File ~/.pyenv/versions/cw/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2939, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2937 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2938 if raise_exceptions:
# -> 2939     result.raise_error()
#    2940 elif not result.success:
#    2941     break
#
# File ~/.pyenv/versions/cw/lib/python3.9/site-packages/IPython/core/interactiveshell.py:268, in ExecutionResult.raise_error(self)
#     266     raise self.error_before_exec
#     267 if self.error_in_exec is not None:
# --> 268     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /tmp/ipykernel_28896/2799263322.py:7
#       5         scope.con()
#       6 except NameError:
# ----> 7     scope = cw.scope()
#       9 try:
#      10     if SS_VER == "SS_VER_2_1":
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/__init__.py:383, in scope(scope_type, name, sn, idProduct, bitstream, force, prog_speed, **kwargs)
#     380         raise ValueError
#     382 if scope_type is None:
# --> 383     scope_type = get_cw_type(**kwargs)
#     384 rtn : scopes.ScopeTypes = scope_type()
#     385 try:
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/common/utils/util.py:522, in get_cw_type(sn, idProduct, hw_location, **kwargs)
#     519     possible_ids = [0xace0, 0xace2, 0xace3, 0xace5]
#     521 cwusb = NAEUSB_Backend()
# --> 522 device = cwusb.find(serial_number=sn, idProduct=possible_ids, hw_location=hw_location)
#     523 name = device.getProduct()
#     524 cwusb.usb_ctx.close()
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:366, in NAEUSB_Backend.find(self, serial_number, idProduct, hw_location)
#     363 def find(self, serial_number : Optional[str]=None, idProduct : Optional[List[int]]=None,
#     364     hw_location : Optional[Tuple[int, int]]=None) -> usb1.USBDevice:
#     365     # check if we got anything
# --> 366     dev_list = self.get_possible_devices(idProduct, attempt_access=(not hw_location))
#     367     if len(dev_list) == 0:
#     368         raise OSError("Could not find ChipWhisperer. Is it connected?")
#
# File ~/Documents/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:490, in NAEUSB_Backend.get_possible_devices(self, idProduct, dictonly, attempt_access)
#     487                 dev_list.remove(dev)
#     489         if len(dev_list) == 0:
# --> 490             raise OSError("Unable to communicate with found ChipWhisperer. Check that \
#     491 \nanother process isn't connected to it and that you have permission to communicate with it.")
#     493         return dev_list
#
# OSError: Unable to communicate with found ChipWhisperer. Check that
# another process isn't connected to it and that you have permission to communicate with it.

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd ../../../hardware/victims/firmware/simpleserial-aes
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3

# %%
fw_path = '../../../hardware/victims/firmware/simpleserial-aes/simpleserial-aes-{}.hex'.format(PLATFORM)
cw.program_target(scope, prog, fw_path)

# %%
project = cw.create_project("traces/STM32F4_HW_AES.cwp", overwrite=True)

# %%
#Capture Traces
from tqdm import tnrange, trange
import numpy as np
import time

ktp = cw.ktp.Basic()

traces = []
N = 20000  # Number of traces
scope.adc.samples=2000

scope.gain.db = 32
scope.glitch.arm_timing = "no_glitch"


for i in trange(N, desc='Capturing traces'):
    key, text = ktp.next()  # manual creation of a key, text pair can be substituted here

    trace = cw.capture_trace(scope, target, text, key)
    if trace is None:
        continue
    project.traces.append(trace)

print(scope.adc.trig_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-15a353580cc4> in <module>
#       4 import time
#       5
# ----> 6 ktp = cw.ktp.Basic()
#       7
#       8 traces = []
#
# NameError: name 'cw' is not defined

# %%
scope.dis()
target.dis()
